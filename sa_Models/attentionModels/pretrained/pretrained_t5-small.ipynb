# %% [markdown]
# https://shap.readthedocs.io/en/latest/example_notebooks/text_examples/sentiment_analysis/Emotion%20classification%20multiclass%20example.html
#
# https://towardsdatascience.com/what-makes-your-question-insincere-in-quora-26ee7658b010

# %%
import torch
import shap
import transformers
import pandas as pd
import numpy as np
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
id = 6

# %%
if torch.cuda.is_available():
    GPU = torch.cuda.get_device_name(id)
    print(f"PyTorch available GPU: {GPU}")
else:
    print("GPU not available")
# Out:
# PyTorch available GPU: Quadro RTX 8000

# %%
torch.cuda.device_count()
# Out:
# 8

# %%
device = torch.device(f"cuda:{id}" if torch.cuda.is_available() else "cpu")
print(f'Device: {device}')
# Out:
# Device: cuda:6

# %%
# device = torch.device("cpu")
# print(f'Device: {device}')

# %%
# Load the pre-trained BERT model and tokenizer
#mod = "mistralai/Mistral-7B-v0.1"
model_name = "google-t5/t5-small"
pretrained = "/home/patrick.araujo/llama2/t5-small_sentiment_model"
model = AutoModelForSequenceClassification.from_pretrained(pretrained).cuda()
tokenizer = AutoTokenizer.from_pretrained(model_name)

# build a pipeline object to do predictions
pred = transformers.pipeline(
    "text-classification",
    model=model,
    tokenizer=tokenizer,
    device=0,
    return_all_scores=True,
)
# Out:
# `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.

# %%
explainer = shap.Explainer(pred)

# %%
dataset = pd.read_csv('/home/patrick.araujo/llama2/datasets/NewAmazonDataset_US.csv')

# %%
dataset
# Out:
#                                  reviewId              userName  \
# 0    a1c885bc-b577-4a5d-ae86-3de77ebb8d90  Jenny From the block
# 1    4e9fe778-291e-45e0-b938-9c5aad81953f                Hulken
# 2    151066cd-1b10-418c-a8cb-4975a27834a7       Sylvia Figueroa
# 3    3d59bd13-0651-4709-9ffe-d35a4afd7a1c        P N (litesabr)
# 4    2154136b-8a7d-4f85-90af-1387927623b4        Ruth Rodriguez
# ..                                    ...                   ...
# 637  4046ff17-1297-47dd-a9c8-7c167d0dc12c      Cristian Andrade
# 638  146c4cf3-e197-4503-9f85-52521037ce6d           Jansen Wong
# 639  5b0c6b0a-284a-4794-aca9-a456a9a4b42c            Princewill
# 640  bdcd49d3-b33e-4855-9ad1-b2c2df2243ab        Phyllis Powers
# 641  262a4bbd-37f0-4270-9605-a6f7013e7625           Lynn Crosby
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ALV-U...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# 3    https://play-lh.googleusercontent.com/a-/ALV-U...
# 4    https://play-lh.googleusercontent.com/a-/ALV-U...
# ..                                                 ...
# 637  https://play-lh.googleusercontent.com/a-/ALV-U...
# 638  https://play-lh.googleusercontent.com/a-/ALV-U...
# 639  https://play-lh.googleusercontent.com/a/ACg8oc...
# 640  https://play-lh.googleusercontent.com/a/ACg8oc...
# 641  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                content  score  thumbsUpCount  \
# 0    Great app for shopping but it won't show my or...      4              0
# 1    Delivery is extremely inconsistent! I pay for ...      3              2
# 2    Always get what im looking for and never had p...      5              1
# 3    So many options that sometimes it's hard to fi...      5              3
# 4             This is where I bought my first computer      5              0
# ..                                                 ...    ...            ...
# 637  I really like buying on Amazon, every transact...      5              0
# 638  Recently after the interface update, it really...      1             14
# 639  Each time I see a recommendation on my notific...      2              1
# 640  Mostly good. Some products are not as good as ...      4              0
# 641                   Don't know what they are doing?!      1              1
#
#     reviewCreatedVersion                   at  replyContent  repliedAt  \
# 0             28.2.2.100  2024-02-03 23:45:21           NaN        NaN
# 1             28.1.0.100  2024-01-21 18:07:15           NaN        NaN
# 2             28.2.2.100  2024-01-28 00:38:31           NaN        NaN
# 3             28.1.0.100  2024-01-21 19:34:33           NaN        NaN
# 4             28.3.0.100  2024-02-13 22:52:04           NaN        NaN
# ..                   ...                  ...           ...        ...
# 637           28.2.2.100  2024-02-05 06:15:03           NaN        NaN
# 638           28.2.2.100  2024-01-29 18:46:13           NaN        NaN
# 639           28.3.0.100  2024-02-15 07:21:03           NaN        NaN
# 640           28.2.2.100  2024-02-11 12:34:52           NaN        NaN
# 641                  NaN  2024-01-25 01:16:42           NaN        NaN
#
#      appVersion  sentiment Language
# 0    28.2.2.100          2       en
# 1    28.1.0.100          1       en
# 2    28.2.2.100          2       en
# 3    28.1.0.100          2       en
# 4    28.3.0.100          2       en
# ..          ...        ...      ...
# 637  28.2.2.100          2       en
# 638  28.2.2.100          0       en
# 639  28.3.0.100          0       en
# 640  28.2.2.100          2       en
# 641         NaN          0       en
#
# [642 rows x 13 columns]

# %%
# Define a custom function to map scores to sentiment
# def map_score_to_sentiment(sentiment):
#     if sentiment == 0:
#         return 'positive'
#     elif sentiment == 1:
#         return 'neutral'
#     elif sentiment == 2:
#         return 'negative'
#     else:
#         return None  # Handle other cases if needed

# %%
data = pd.DataFrame({"text": dataset["content"], "emotion": dataset["sentiment"]})

# %%
#data = pd.DataFrame({"text": dataset["content"], "emotion": dataset['sentiment'].apply(map_score_to_sentiment)})

# %%
shap_values = explainer(data["text"][:3])
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   0%|          | 0/498 [00:00<?, ?it/s]
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer:  67%|███████████████▎       | 2/3 [00:00<?, ?it/s]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 4it [00:23, 11.70s/it]

# %%
shap.plots.text(shap_values)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_mzwfzgurggdqjifdcynr = '_tp_mzwfzgurggdqjifdcynr_output_0';
#     document._zoom_mzwfzgurggdqjifdcynr = undefined;
#     function _output_onclick_mzwfzgurggdqjifdcynr(i) {
#         var next_id = undefined;
#
#         if (document._zoom_mzwfzgurggdqjifdcynr !== undefined) {
#             document.getElementById(document._zoom_mzwfzgurggdqjifdcynr+ '_zoom').style.display = 'none';
#
#             if (document._zoom_mzwfzgurggdqjifdcynr === '_tp_mzwfzgurggdqjifdcynr_output_' + i) {
#                 document.getElementById(document._zoom_mzwfzgurggdqjifdcynr).style.display = 'block';
#                 document.getElementById(document._zoom_mzwfzgurggdqjifdcynr+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_mzwfzgurggdqjifdcynr).style.display = 'none';
#                 document.getElementById(document._zoom_mzwfzgurggdqjifdcynr+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_mzwfzgurggdqjifdcynr !== '_tp_mzwfzgurggdqjifdcynr_output_' + i) {
#             next_id = '_tp_mzwfzgurggdqjifdcynr_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_mzwfzgurggdqjifdcynr = next_id;
#     }
#     function _output_onmouseover_mzwfzgurggdqjifdcynr(i, el) {
#         if (document._zoom_mzwfzgurggdqjifdcynr !== undefined) { return; }
#         if (document._hover_mzwfzgurggdqjifdcynr !== undefined) {
#             document.getElementById(document._hover_mzwfzgurggdqjifdcynr + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_mzwfzgurggdqjifdcynr).style.display = 'none';
#         }
#         document.getElementById('_tp_mzwfzgurggdqjifdcynr_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_mzwfzgurggdqjifdcynr = '_tp_mzwfzgurggdqjifdcynr_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.18019409784115661); border-radius: 3px; padding: 0px" id="_tp_mzwfzgurggdqjifdcynr_output_0_name"
#     onclick="_output_onclick_mzwfzgurggdqjifdcynr(0)"
#     onmouseover="_output_onmouseover_mzwfzgurggdqjifdcynr(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_mzwfzgurggdqjifdcynr_output_1_name"
#     onclick="_output_onclick_mzwfzgurggdqjifdcynr(1)"
#     onmouseover="_output_onmouseover_mzwfzgurggdqjifdcynr(1, this);">LABEL_1</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.6846900376312143); border-radius: 3px; padding: 0px" id="_tp_mzwfzgurggdqjifdcynr_output_2_name"
#     onclick="_output_onclick_mzwfzgurggdqjifdcynr(2)"
#     onmouseover="_output_onmouseover_mzwfzgurggdqjifdcynr(2, this);">LABEL_2</div><br><br><div id='_tp_mzwfzgurggdqjifdcynr_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="48.447054808831666%" y1="33" x2="48.447054808831666%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="48.447054808831666%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="33.59911246074236%" y1="33" x2="33.59911246074236%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="33.59911246074236%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="18.751170112653064%" y1="33" x2="18.751170112653064%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.751170112653064%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="63.294997156920964%" y1="33" x2="63.294997156920964%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.294997156920964%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="78.14293950501026%" y1="33" x2="78.14293950501026%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="78.14293950501026%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="29.077457076951283%" y1="33" x2="29.077457076951283%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="29.077457076951283%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.108641</text><text x="29.077457076951283%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.108641</text><text x="29.077457076951283%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="28.475612947740192%" y1="33" x2="28.475612947740192%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="28.475612947740192%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.0964806</text><text x="28.475612947740192%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.0964806</text><text x="28.475612947740192%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="5.875419218662754%" width="22.600193729077436%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="23.38884755493004%" x2="28.475612947740192%" y1="60" y2="60" id="_fb_lenxnladlbvwwpjzizsx_ind_13" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="25.932230251335117%" y="71" font-size="12px" id="_fs_lenxnladlbvwwpjzizsx_ind_13" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.103</text><svg x="23.38884755493004%" y="40" height="20" width="5.08676539281015%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">keeps</text>  </svg></svg><line x1="18.3987507984849%" x2="23.38884755493004%" y1="60" y2="60" id="_fb_lenxnladlbvwwpjzizsx_ind_14" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="20.89379917670747%" y="71" font-size="12px" id="_fs_lenxnladlbvwwpjzizsx_ind_14" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middl ...

# %%
# Move model to GPU
model = model.to(device)

# %%
comments = dataset['content']

# %%
predictions = []
i = 0
for comment in comments:
    encoded_input = tokenizer(comment, return_tensors="pt")
    encoded_input = {k: v.to(device) for k, v in encoded_input.items()}
    output = model(**encoded_input)
    prediction = torch.argmax(output.logits, dim=-1)
    sentiment = "Negative" if prediction.item() == 0 else "Neutral" if prediction.item() == 1 else "Positive"
    prediction = prediction.item()
    predictions.append(prediction)
    i = i+1
    print(f'Comment {str(i)}: {comment}\tPrediction: {sentiment}')
# Out:
# Comment 1: Great app for shopping but it won't show my orders and keeps glitching. It never used to do that	Prediction: Neutral
# Comment 2: Delivery is extremely inconsistent! I pay for Prime service which means my packages should be delivered to my apartment door. Usually they are dumped in a large pile in our apartment building lobby for all our buildings Amazon customers to sort through. This is frustrating especially for people with limited physical abilities. Try to express this to a human at Amazon and there is no venue, just bots. So beware if you are considering a Prime membership.	Prediction: Negative
# Comment 3: Always get what im looking for and never had problems with delivery. keep up the hard work. thank hou	Prediction: Positive
# Comment 4: So many options that sometimes it's hard to find things, but then you just search for what setting you need in the search bar, and it comes up. It's so easy. One of the smoothest apps out there, but it is to be expected with being for the largest company on the planet.	Prediction: Positive
# Comment 5: This is where I bought my first computer	Prediction: Positive
# Comment 6: To be honest delivery took so long that I couldn't use it	Prediction: Negative
# Comment 7: Very bad, I will just go to Amazon. Ca	Prediction: Negative
# Comment 8: Love this shopping app. Has everything I need and want	Prediction: Positive
# Comment 9: Amazon is the best online shopping you'll ever need to use ,they're the best!!	Prediction: Positive
# Comment 10: l bont tlnc people who apracuate us deserve to buy wlth us Mr amsnz employe Jeff besoz	Prediction: Positive
# Comment 11: I've. Been a customer for years love it always	Prediction: Positive
# Comment 12: Loved it at first! And still do. My only problem is that I can't buy gift cards like roblox with my gift card balance. Im a teen, meaning I can't work just yet, but they expect me to pay real money?? I have my gift card money and that's it.	Prediction: Positive
# Comment 13: Punch of scamers i returned an order and the app says money refunded back on the 14th of Jan and they kept contacting me by emails on my mail box asking for documents till 25th of Jan and till now i didn't receive my refund yet I highly don't recommend buying anything from this app as you will be scamed and you won't receive your money back if you returned any order	Prediction: Negative
# Comment 14: One of my favorite apps, use Amazon nearly daily. Has timely updates. Please update app icon to "Material you" and get rid of "shopping" (iOS doesn't have that in the name).	Prediction: Positive
# Comment 15: Super laggy when browsing review photos. Also crashes when shopping. Super laggy in general.	Prediction: Negative
# Comment 16: Why would you move the search bar to the bottom of the app? This ui change made me uninstall and use the mobile browser lmao. Terrible idea! UPDATE : Incredible, they quietly reverted the change. I had to look this up. Still 3 star for pulling this bs!	Prediction: Negative
# Comment 17: unable to display all previous orders, when applying filters you get a list of about 12 previous orders. Strange how it works fine on my phone and kindle fire but not on tablet	Prediction: Neutral
# Comment 18: Amazon has become a wasteland of knockoffs and scam listings, and they couldn't care less. Try reporting listings that use prior 4&5 star ratings from completely different products and nothing happens. 3rd party sellers chronically terrible either not shipping or shipping complete trash. It's like temu or another scammy shopping site, except with those that's the expectation.	Prediction: Negative
# Comment 19: I love amazon I am a prime member but this app is really slow and lagging	Prediction: Neutral
# Comment 20: Use to be a good app but since today, it doesn't work in China. You are forced to re-direct to website amazon.cn and non of the part of the website is click-able. Like a zombie. Very bad. We know you have a separating strategy for Chinese market but why, why confusing us who use global version app? Disappointed 😞.	Prediction: Negative
# Comment 21: I want this app on my cell phone SM-A530W, besides my Galaxy Tab S7FE..thank you.	Prediction: Positive
# Comment 22: shopping online through this app very fast	Prediction: Positive
# Comment 23: I can't even use the app since the latest update it keeps crashing a few seconds every time after it is launched please fix this!	Prediction: Negative
# Comment 24: item turned out to be not what we wanted, item bend when weight is put on it. need updates.	Prediction: Neutral
# Comment 25: I really like Amazon. 👍🏾 The convenience is key for me.	Prediction: Positive
# Comment 26: ok off the top most expensive and the amount is a bit low costs are a bit more flexible than I thought it would like you are looking for the best experience of my account direct to my house to get things done to the right value of your life good situation here but Amazon is the only way that you can get a good feel for the transaction on your website and you can get a new phone number and a new direction in life for me I can give me to be able help out and help me to establish a chance to work	Prediction: Neutral
# Comment 27: I used it for I thought free one time during Christmas, now I'm being charged every month, how do I stop that !!!!	Prediction: Negative
# Comment 28: Burns up to much data. I'm cutting back. Plus charging for fresh delivery . What's the point no savings. Ill just get my own.	Prediction: Negative
# Comment 29: Bring back the "You bought this item at so and so time" back please. It makes absolutely no sense when a customer is very satisfied with a product whether he bought that particular product or something similar. I am assuming this action raises the cost of operations with more returns. It is the MOST useful feature you had. And of course been Amazon your developers have to mess up the good functions.	Prediction: Negative
# Comment 30: No dark mode in 2024. 1 Star until then.	Prediction: Negative
# Comment 31: I love it! I have Prime with so many perks! Fast delivery!	Prediction: Positive
# Comment 32: Ths shld b 5star but over the last 5 yrs or so I've had this feeling like sumthng was OFF... THEN 2DAY IT FINALLY HIT ME!... I remembered when Amazon use to have the option to, if u wanted to add sumthng 2 ur wishlists (n which I have more than I'd like to say ANY OTHER AMAZON SHOPPR ACROSS THE GLOBE) U just had to hold dwn on said item n it wld ask if u wntd 2 add it 2 ur list... PLZ BRING THIS BACK N ILL GLADLY GIVE A 5STAR REVIEW	Prediction: Negative
# Comment 33: For once I wanted to try the functionality "show in your room" but when I'm ready to place virtually the item in my room, the app crashes...	Prediction: Negative
# Comment 34: great co on time and great deals	Prediction: Positive
# Comment 35: Been super slow at getting packages out lately and not just due to storms	Prediction: Negative
# Comment 36: Needs dark mode. Honestly, for as heavily this app is used by people... I'm floored it still lacks dark mode.	Prediction: Neutral
# Comment 37: App constantly shuts down stating a bug. Please fix it	Prediction: Negative
# Comment 38: lm a amazonholic, I love this shitz now go get your amazon on mofo... 5 stars for me, spend dat 💰 🤑 💸	Prediction: Positive
# Comment 39: First item purchased arrived defective and require me to pay $9 to return it because there isn't a ups store near me.(other option was to drive nearly an hour to nearest ups store. Currently have 3 canceled items that they have yet to refund and are claiming they don't have the means to refund. So they are practically stealing. And can't will only talk off of a script and tell me to dispute it with my bank and all foreign. Yall got paid and claiming you didnt. I would give a zero rating.	Prediction: Negative
# Comment 40: absolutely love amazon, especially when you can get next day delivery.	Prediction: Positive
# Comment 41: Everything you could ever need, they have it!	Prediction: Positive
# Comment 42: I love amazon so much... but where is dark mode.???? It's 2024, come on...	Prediction: Positive
# Comment 43: They illegally stole money from my account. I disputed the charges, and they closed my account.	Prediction: Negative
# Comment 44: I am starting not you like Amazon the chargers 👀💔 1499	Prediction: Neutral
# Comment 45: I really need to stay off this app. 😆	Prediction: Positive
# Comment 46: Every now and then the scrolling gets choppy. Not sure what causes it, but it's been an issue for a long time.	Prediction: Neutral
# Comment 47: The ads are ridiculous. They'reoney-grabbing. Amazon is being greedy and trying to nickel and dime customers by adding substantial ad time multiple times to previously ad-free movies and shows. Shame on prime. I want my 40$ back. If I wanted to pay for ads I would stick to cable.	Prediction: Negative
# Comment 48: The new re-design shortcuts list is nice. Makes it easier to find your lists & everything you're looking for. Continue to update for design improvements for a better customer experience....	Prediction: Positive
# Comment 49: English language of application is not avaliable in poland, well done, guys	Prediction: Neutral
# Comment 50: I find it ridiculous to require an app only to open a locker	Prediction: Negative
# Comment 51: I used to think of Amazon as a five-star app and company but ever since they started with the new add programs in the prime video it has gone downhill. As if they're not making enough money off of us they feel the need to put ads in the videos and on top of that the ads are messing with the streaming quality and will stop some videos from playing and cause them to freeze. This is ridiculous and I think 3 stars is actually quite generous. Step it up Amazon, you can do better than this.	Prediction: Negative
# Comment 52: Awesome app. Whatever you do, don't get the prime subscription. Not worth paying, especially when they are late with deliveries. I don't pay and get my deliveries within 2 to 4 days when I order and no prime.	Prediction: Positive
# Comment 53: Someone stole my debit card info and won't assist in helping out with this scenario. I asked of they had a fraud group I could speak to and was told no. Seriously thinking about deleting my subscription because of this whole ordeal.	Prediction: Negative
# Comment 54: You can find anything on this fricken app. But they're buying up farm land to build mega warehouses and squeezing out the smaller stores. Sad	Prediction: Negative
# Comment 55: I thought I have a disability and I find it really hard to get outside to go to the shops I find shopping online is the best thing for me so shopping on Amazon is great	Prediction: Positive
# Comment 56: This app will change shipping and shopping location without any permissions or notifications. Called customer service, they didn't understand and were horrible. Fixed it eventually without help and ridiculous inconveniences.	Prediction: Negative
# Comment 57: Really convenient and great bulk buys	Prediction: Positive
# Comment 58: Does what it says on the tin brill	Prediction: Neutral
# Comment 59: Why is there more prime content than Blu-rays or DVDs when it comes to looking for a movie anymore? I'm not understanding this.	Prediction: Neutral
# Comment 60: I love amazon. i can always find what I need at a reasonable price.	Prediction: Positive
# Comment 61: Amazon is good until it's not. They cancelled an order but didn't list it as cancelled in my ORDERS . It was just gone, like I'd never ordered it. When it didn't arrive I couldn't retrieve it in ORDERS because ... it was gone. When I called them, they said it was canceled. Okay, how about telling me so?! I didn't receive the package on time for a costume party. Thanks allot.	Prediction: Negative
# Comment 62: Customer service is not what it could be. The app updated, the currency and country set itself to USD, US and my past and present orders vanished. All ok on web, App spooked me until I figured it out. No way to quickly contact Amazon .. I know they want to advertise so it's many buttons to check on current orders, but really ?!	Prediction: Negative
# Comment 63: Ever since the Amazon update, I have had the looping problems of going back to Proceed to checkout. I have deleted my app. I have gone to the website. I've called 3x and they keep putting a ticket in and said wait 24 to 48 hours. This is the third ticket I have put in. They tell me its not been resolved (duh). I have a gift card balance and I'd just say screw it and just not use Amazon again. I know it would he hard because it's a great online shopping service, but useless if I can't use it	Prediction: Negative
# Comment 64: You stole my money. And won't give it back.	Prediction: Negative
# Comment 65: Incredibly slow, chocked full of ads. Shady transaction tactics.	Prediction: Negative
# Comment 66: I enjoy buying my stuff at Amazon. I love it.	Prediction: Positive
# Comment 67: moved countries, have new phone #..so now cant open	Prediction: Negative
# Comment 68: Constantly crashes and your orders option never works	Prediction: Negative
# Comment 69: Amazon is very n scammer I pay my loptap for urgent my class but untill is not come they said is wrong address, i have ah number but the carrier why not call to send my location, dont order any item to this apps.	Prediction: Negative
# Comment 70: I like Amazon I just don't appreciate my package being thrown over the fence instead of being placed on my front door where it's supposed to be.	Prediction: Neutral
# Comment 71: good service but watch out some are higher priced and shipp from foreign countries and no after sale service	Prediction: Positive
# Comment 72: I CANT FIND ALASTOR ITEMS AND IT KEEPS GLITCHING 😡😡😡😡😡	Prediction: Positive
# Comment 73: Bro the app you know I put my email and then like it putted me on someones other email account and then like other people showed up on my account and then like the website just acts strange	Prediction: Neutral
# Comment 74: The Amazon website has come a long way. It is so easy to navigate now and user friendly.	Prediction: Positive
# Comment 75: Constant lags and freezes. Won't let me check my orders without having to wait for 10 minutes.	Prediction: Negative
# Comment 76: sweet. no problems so far! excellent service.	Prediction: Positive
# Comment 77: Delivery has never been late, incorrect or not as advertised, so far.	Prediction: Positive
# Comment 78: Bro this app is so bad literally everything I buy comes broken and nothing came good except a PC mouse I mean bro this app is the worst	Prediction: Negative
# Comment 79: very useful, prime delivery is awesome, great selection. never had an issue.	Prediction: Positive
# Comment 80: It Great to get products delivered straight to your door. THANKS AMAZON TEAM	Prediction: Positive
# Comment 81: Love prime shopping. Next day delivery is great!	Prediction: Positive
# Comment 82: too much stuff going on it used to be pretty straight forward now there Are flashing lights everywhere I look.	Prediction: Neutral
# Comment 83: Can't clear search bar. Also slow to load images and selections	Prediction: Negative
# Comment 84: great way to shop when house bound and great value for money .any problems solved over the phone	Prediction: Positive
# Comment 85: Shopping on Amazon is very easy. you can search for almost anything and have it shipped to your door.	Prediction: Positive
# Comment 86: This is the quality of app you would expect from a company with a monopoly. It absolutely sucks, from the layout to performance. The Whole Foods section is extremely buggy. Craps out adding groceries to the cart	Prediction: Negative
# Comment 87: I have has the app for a time .I put all the things I want to order .when I think of them .I when to the Amazon shipping app all that I had the in the cart Re gone things	Prediction: Positive
# Comment 88: So safe and easy to use, I recommend malls,shops and households to buy this product but there are a few adjustments to be made on sizes of the machine	Prediction: Positive
# Comment 89: I love shopping at Amazon , I always get my packages on time.	Prediction: Positive
# Comment 90: Keep tweaking out, when I go to review my orders I can't even stroll through it because it just keeps tweaking out blinking can't do anything	Prediction: Negative
# Comment 91: Amazon sucks now. They used to be good. They take your money right away when you order stuff. They used to wait until they shipped your items before taking money out of your account. I need to cancel items, and now my account is messed up. Also, their prices on electronics are ridiculous. You can find cheaper stuff at Best Buy.	Prediction: Negative
# Comment 92: Prices continue to go up. Delivery is slower.	Prediction: Negative
# Comment 93: Very first time I EVER BOUGHT MY SELF ANYTHING FROM AMAZON..	Prediction: Positive
# Comment 94: I placed an order Dec, 29th I don't know why they still haven't taken out the full payment? Update: it tried just a few minutes ago to pull the payment after over a week of being on order status naturally in that time I had to put the payment in my savings so it wouldn't be spent a little heads up or purchases completed sooner so that I'm not left wondering if it's ever going to finish	Prediction: Negative
# Comment 95: Orders are often late. Not reliable enough yet when you need an item by a set date.	Prediction: Negative
# Comment 96: Very nice Amazon sopping and very fast dalwrey	Prediction: Positive
# Comment 97: It's decent, I added a gift card but after 3 days it just disappeared and I had only used half the balance. Doesn't do that with the website	Prediction: Neutral
# Comment 98: App is not working right please fix	Prediction: Negative
# Comment 99: Trying to buy anything has become a problem. You buy something and most of the time what you get is nothing like the description or it's missing items. Customers service response every time is return it. I don't want to keep returning stuff I want what I paid for	Prediction: Negative
# Comment 100: Everything is so expensive and have shipping	Prediction: Negative
# Comment 101: Customer service is non-existent. The crazy amount I've spent with only 3 or 4 returns, I have no link for customer service chat and no number to call. Guess I'll buy from other apps or just local. It is easier if there is an issue. The last time I tried contacting them, I had to go through the US chat just to get a Canadian phone number. With all my orders, it's very rare I need to contact them.	Prediction: Negative
# Comment 102: great experience great book price 58 euro, expensive post charges 54 euro . 1 book at great price , postage equal price .	Prediction: Positive
# Comment 103: Practical shopping experience. Shipping much better than Ebay sellers.	Prediction: Positive
# Comment 104: The app has become extremely difficult to use. It slows down to the point where pages take several minutes to load or just don't load at all, ending up by crashing and having to be force-closed. It's nothing to do with my phone - all other apps work fine and my phone is more than powerful enough to handle what should be a simple shopping app. An app like this should not cause these problems. Save frustration and shop through the browser. Or just shop elsewhere.	Prediction: Negative
# Comment 105: Shopping...just too busy to go shopping, and glad to have them. Saves so much time.	Prediction: Positive
# Comment 106: Just use your browser and go to the website cause the app is not a regular app. When Jezuz takes control of the nations of the earth after saving the Izraelites at the last second, then this app will function properly. (Pzalms 2:6-9, Revelashion 11:15)	Prediction: Neutral
# Comment 107: Woke up, and this app is in Spanish. Followed online directions to change language. English isn't an option. I did an update, still in Spanish. The update removed thee option to change languages. Trouble shooting said I may have selected a page or link through my browser that's overriding the language settings on the app. Checked. Nope, it's in English. In the browser, Amazon is in English. So I'm uninststalling the app. Fixed!	Prediction: Negative
# Comment 108: can't zoom in on product pictures from customers. App comes back with responses that don't match description due to sponsored items.	Prediction: Negative
# Comment 109: Amazon want to take over my phone. Now when I highlight anything, my first option is to search Amazon for it. The App is in dire danger of being deleted. Strangely, the problem above has stopped. We will see.	Prediction: Negative
# Comment 110: I'm not able to review products, but Amazon can't explain why.	Prediction: Neutral
# Comment 111: You allowed 95 pounds to be withdrawn from my account and this is the second time it has happened!!! Are you a thief?!	Prediction: Negative
# Comment 112: I always find what I'm looking for, for a nice price with quick delivery	Prediction: Positive
# Comment 113: I have been having difficulty placing this order.	Prediction: Positive
# Comment 114: Bring back old app on pages selection	Prediction: Neutral
# Comment 115: This doesn't fit my phone so I only reinstall when needed.	Prediction: Neutral
# Comment 116: Ever since new update when I want to share a product thru text it doesn't send the link anymore, just the name of the item.	Prediction: Negative
# Comment 117: Always cancelled my order or locked the account	Prediction: Negative
# Comment 118: I have a mobility disability, so I hate store shopping. Amazon is my main go-to for things that I need... or just want. My family knows that any time there is a gift, Amazon gift cards are a sure bet to be liked. Returns couldn't be any simpler, and any products that have issues are easy to get replaced. HOWEVER, I MISS 2 DAY SHIPPING!	Prediction: Positive
# Comment 119: It's Amazon what do you expect.	Prediction: Positive
# Comment 120: I wish you google would leave my apps alone	Prediction: Neutral
# Comment 121: This is the far most shopping experience I've ever had. Great prices, and I'm also an amozon prime member, which is also a great price per month.	Prediction: Positive
# Comment 122: Hamburger menu on lower right hand corner, really? I wonder how you tested the latest app it has both usability and stability issues 🤔	Prediction: Neutral
# Comment 123: Try to look up items goes to "oh sorry having problem go back to Amazon home. This is very irritating seeing how much I look for what I need. And I have prime.	Prediction: Negative
# Comment 124: I still have a lot to learn about Amazon shopping, but still, I love it so much.	Prediction: Positive
# Comment 125: Not user friendly layout. Too much clutter and complicated options that are not useful. Terrible UX	Prediction: Negative
# Comment 126: Can't access the app. Everytime I open it, it says there's been an error. This began after the update.	Prediction: Negative
# Comment 127: I've been shopping with Amazon since they only sold books. I love the convenience of shopping online instead of running all over town looking for what I need.	Prediction: Positive
# Comment 128: I can fine what I what by look for it but it abit rubbish and need a lot of improvement as it's a UK site but the sell from all over the place if you say you a UK site stick no UK regent please and get some English speakers on the phones the understand what you are asking for us UK people thanks	Prediction: Neutral
# Comment 129: so easy to use and can find so many deals on here ..luv it..	Prediction: Positive
# Comment 130: They made me pay amazon prime for no reason, making it hard to contact about amazon prime	Prediction: Negative
# Comment 131: Having issues with app when it comes to tax exempt and taking tax exempt status off. It's available thru the web browser but not the app itself. Please fix!	Prediction: Neutral
# Comment 132: My card keeps declined with the app its beyond a joke its really annoying I just wanted to order 3 things I give up with this app I'm fed up of it amazon sort yourself out or im gonna uninstall the app fully	Prediction: Negative
# Comment 133: It's turning into a mombo jumbo app. Starting 2024, the "get it today" option is no longer real. They put it before you pay, and they update it later on to next day delivery	Prediction: Negative
# Comment 134: Awful just updated and still not showing EBT amount. Going off and on . Slow down	Prediction: Negative
# Comment 135: I don't shop online I don't feel I will need this app what do you suggest thank you Barry	Prediction: Positive
# Comment 136: I love it. I don't know what I used to do before Amazon	Prediction: Positive
# Comment 137: Good app in the world one of the best shopping online app😇🌍	Prediction: Positive
# Comment 138: no place better is than amazon only a couple of things in 2 stores that I would need I'm very good at finding everything amazon is the best perfect thank you amazon l love your return policy too so ez and Friendly's your simply the best hope you find what your looking for investing on going to the. 🌙 moon all good be with you your interested costumer jerry in inventor of magnet device 100 present free energy on battery only magnets static (thank you!	Prediction: Positive
# Comment 139: For the last several months the app gets so laggy and glitchy. Closes randomly often. I keep the cache cleared and the app updated.	Prediction: Negative
# Comment 140: drivers do not do as asked when delivering and leave in.the rain	Prediction: Negative
# Comment 141: It is good app for shopping, but need direct email to customer service. Return issue. Winter coat too big but unable to return even Amazon has 30 days return policy. I'm applied return process approx 20 times now but return request disappears from order. So £90 just wasted for coat what doesn't fit.	Prediction: Neutral
# Comment 142: other then a few screw ups and refunds. its ok	Prediction: Positive
# Comment 143: Love the services but the app is not user friendly especially on loading content. Loading is very slow given that I am already using a 5G network or even Wifi 6. Loading the Account is double the speed of slow. Well if that is because of security then I am fine if not.. it is bad.	Prediction: Neutral
# Comment 144: I'm not sure about the is app bc all you can do is just look at stuff and buy it but that is just my opinion	Prediction: Neutral
# Comment 145: I payed extra shipping for fast delivery & it got delayed so I cancelled & they just never gave me my money back. With another more expensive order it just never showed up & they even allow you to supposedly request a refund but it doesn't do anything. These are only 2 recent orders amazon has stolen from me without reimbursement but this hasn't been the first time. Not even close. Amazon is shadier than you think so shop with caution.	Prediction: Negative
# Comment 146: Dont get me wrong, I love Amazon and prefer it over any other competitor, but this app is starting to frustrate me the more I use it. On mobile, the app straight upp sucks. It lags a lot, videos and pictures take years to play and will freeze the app anyways. (I cleared the cache too) Searching for specific items always gives me things that aren't even remotely close to what I entered. Other than that, its a great app but can get extremely frustrating at times	Prediction: Neutral
# Comment 147: Constantly having issues, and i keep getting locked out of my account for no reason. Other than that, the app works well and deliveries are usually on time.	Prediction: Positive
# Comment 148: Two things that would make the app much better: 1. Dark mode 2. Being able to filter by Returns in the your-orders section	Prediction: Neutral
# Comment 149: App works great except I can never get the view in room feature to work. All permissions given and when I tap to place the item the app crashes	Prediction: Negative
# Comment 150: I really like shopping on Amazon. I can almost always find what I am looking for and the prices are very reasonable.	Prediction: Positive
# Comment 151: They are not what they used to. My item was delayed indefinitely, after waiting for a week.	Prediction: Negative
# Comment 152: I hate bc it lets people steal ur information on it	Prediction: Negative
# Comment 153: I love this helps me get what I need when I need it Great app	Prediction: Positive
# Comment 154: Overall, it's okay. I dislike that for the hub that Amazon claims to be its almost impossible to find items that fit into my style and I would have a much better chance at finding something better through a different site even it was more difficult to obtain. Also please make a dark mode.	Prediction: Neutral
# Comment 155: Please please we want Dark mode for night time viewing thx.	Prediction: Neutral
# Comment 156: Added invasive features to my text selection throughout all my other apps; including text messaging and broswer.	Prediction: Negative
# Comment 157: I have a bad experience with customer service they never solved my issue specially 😕 on refund .	Prediction: Negative
# Comment 158: I like it with the tracking bit . To see where it is and the messages with . I'm 😁😁😁	Prediction: Positive
# Comment 159: Very good app but need more stuff that sips into nepal	Prediction: Positive
# Comment 160: everytime I order it comes late	Prediction: Negative
# Comment 161: Great experience good products and on time	Prediction: Positive
# Comment 162: This is a good app for everyone	Prediction: Positive
# Comment 163: You're paying for a prime membership for free shipping but they just increase the price of a product to include shipping costs, thereby hiding the cost of shipping. This sort of underhanded and predatory business practice will make me cancel my membership. They're not "Customer Obsessed", they're "Money Obsessed".	Prediction: Negative
# Comment 164: I love the convenience of Amazon. I give it this rating because I'm frustrated with the marketing emails recommending the purchase of the same product or another version of it. I don't need 2 of the same products or I would have bought 2 or 3. Stop suggesting another brand of the same product because the repeat emails are frustrating	Prediction: Neutral
# Comment 165: with prime in your own country a good deal, but abroad the shipping costs are way too high even within Europe. From Germany to the Netherlands for 12 euro is ridiculous.	Prediction: Neutral
# Comment 166: Ads with Prime?! Seriously?! Why keep downgrading the subscription?! Greed and lack of customer appreciation has ruined yet another good thing.	Prediction: Negative
# Comment 167: It's soooo slow. I've updated it so many times and it does not work. It's wild.	Prediction: Negative
# Comment 168: Geesh, you can find d anything on here. The bad part art? They put small businesses out of business. To monopolizing of a site.	Prediction: Negative
# Comment 169: Great way to order supplies for my mom. Always quick, easy and great prices!	Prediction: Positive
# Comment 170: The app is very slow I need to wait 5 minets to load the item	Prediction: Negative
# Comment 171: Doesn't have what I'm looking for	Prediction: Neutral
# Comment 172: I'd love to order online by Amazon for personal tools.	Prediction: Positive
# Comment 173: I know you guys got $3,000 for my money right now that I just won the money	Prediction: Positive
# Comment 174: quick free delivery with Amazon Prime	Prediction: Positive
# Comment 175: Scrolling down the app to the reviews section makes it so laggy it scrolls down on its own and rendering it hard to read reviews.	Prediction: Negative
# Comment 176: Great app. Truly love it. Could there be a feature that allows you to mark an order as received? I've had orders from months ago that day "On its way but running late."	Prediction: Positive
# Comment 177: Daily with lots of new & innovation, content & products!! 👍👍 Keep going!!	Prediction: Positive
# Comment 178: I can not use it. My instructions was to leave it at my door step.	Prediction: Negative
# Comment 179: Accidentally bumped button to switch from English to Spanish. Once activated couldn't get it returned to english	Prediction: Negative
# Comment 180: Up until a month ago, I've had good service from Amazon, but it has been the third time this month that my packages has either been delayed or not arrived on the date it said it would arrive, very disappointed in Amazon.	Prediction: Neutral
# Comment 181: They lie about your delivery and this is my last time I order anything from them...	Prediction: Neutral
# Comment 182: The latest update completely broke Amazon on my S23 Ultra running android 14. It constantly freezes, lags and I have to constantly clear the cache as it is 300mb+. Recent update also has not fixed the issue.	Prediction: Negative
# Comment 183: Take the money when we confirm the order.	Prediction: Positive
# Comment 184: poor consumer protections from ADMIN of Amazon Prime. W/O written warning, Amazon chgd my Prime Subscription! Suspect new Medical Dept may operate dame way if I order prescriptions. Unhappy Consumer in Scittsdale, AZ	Prediction: Negative
# Comment 185: The View in Room feature for products is crashing the app, latest Android software, Samsung Fold phone	Prediction: Negative
# Comment 186: Amazon in Egypt different from any part of the world they cancel order and rasing price to buying it by high price! Not recommended in Egypt	Prediction: Negative
# Comment 187: I Love Amazon and their free shipping BUT, I wish that the lowest price would come up on the items we search	Prediction: Positive
# Comment 188: You can never pull up orders without it glitching. I dont know if there was an update for that	Prediction: Neutral
# Comment 189: I can always find what I want and get it fast.	Prediction: Positive
# Comment 190: I always find what I'm looking for	Prediction: Positive
# Comment 191: Great site,accurate listing with timely delivery 5*	Prediction: Positive
# Comment 192: The delivery is okay. but when I had to buy something, Amazon had pretty much of a bug problem. One of my orders had been delivered in the wrong side of a house when I didn't specifically want it placed to that spot. I was accused by my guardian even though it was my order while I am living in her house.	Prediction: Neutral
# Comment 193: I love that I can find exactly what I want/need at a good price plus free shipping for Prime members, and also, Amazon Shopping has an excellent return policy.	Prediction: Positive
# Comment 194: I don't like that Amazon & similar conglomerates (you hear me, Walmart) have driven so many Mom/Pop & other small businesses - out of business! Amazon has become almost a necessary evil!	Prediction: Negative
# Comment 195: Can't open the app since the last update. Please fix. Even when I don't have the app open, I am getting error messages about it saying Amazon shopping keeps closing.	Prediction: Negative
# Comment 196: Worst experience,worst customer service. I didn't even received my order after payment.	Prediction: Negative
# Comment 197: This is the best app to shop. Order Comes early. Best delivery	Prediction: Positive
# Comment 198: Julio Camarillo Amazon order is in my email ✉️ I was just trying to find a new 🆕 for me and you $$$$$$	Prediction: Positive
# Comment 199: When looking for anything when you put into the search bar exactly what you are looking for it should bring up exactly what you are shopping for. Not everything in that category!!! And in filters, when you mark all the things that can best describe what you are looking for show it not everything in that category!!! PNMA	Prediction: Neutral
# Comment 200: Average. Far too many uh oh something went wrong errors. The cute dog pictures are now irritating rather than funny.	Prediction: Negative
# Comment 201: I never had any reason issued. just a few, and they were solved with no problems.	Prediction: Positive
# Comment 202: App is glitchy. Bounces up and down after I search a question. Is there an update?	Prediction: Neutral
# Comment 203: I have spent $10s of $1000s of dollars with Amazon and have always been satisfied even when there was a mix up with size shape color or wrong item shipped whatever the issue always been satisfied with the Amazon return or refund. I've never considered closing my Amazon account (I participate in the shopper panel monthly so it pays for itself really) I AM SERIOUSLY CONSIDERING CLOSING MY AMAZON ACCOUNT LATELY. I turned the items in to ups Jan 4. My refund still hasn't been issued. HASTLE=UNWORTHY	Prediction: Negative
# Comment 204: It'd be better if there's many vouchers I can get	Prediction: Positive
# Comment 205: Failure to deliver product but say you did is starting to get old. Feel like Amazon steals more money from me rather then me actually buying something	Prediction: Negative
# Comment 206: Amazing items it was amazingly fast delivery and it did it before the "incident"	Prediction: Positive
# Comment 207: You guys need to make a dark background for Amazon its to bright to use amazon my eyes burning	Prediction: Neutral
# Comment 208: I live in france but I use English as main language. It's available for every country except here ? No f way.	Prediction: Positive
# Comment 209: Amazon has become opaque & untrastable. I purchased a blender from the Amazon app, which claims to be sold by Amazon and selected by Amazon. Once I received the package 📦 inside the box, all the items were used and scratched. I expressed my concerns and my opinion regarding the "quality check" before delivery to the consumer, but unfortunately I was not even allowed to highlight and was asked to change the comments that were given. I'm a loyal Prime member though...	Prediction: Neutral
# Comment 210: Why can't I get this on my home screen	Prediction: Neutral
# Comment 211: service about the same with management changes however not reciprocal with my client quality. disappointed. looking to speak with native English agents from now on	Prediction: Neutral
# Comment 212: most everything I need they have. price and fast shipping a plus	Prediction: Positive
# Comment 213: Very bad experience with this stupid app.	Prediction: Negative
# Comment 214: Amazing when everything is okay but if you need help from customer service then you might as well play backgammon.	Prediction: Positive
# Comment 215: so easy to use, great range of products. great prices	Prediction: Positive
# Comment 216: This is a very good app. I enjoy shopping here.	Prediction: Positive
# Comment 217: I've consistently ordered a variety of things through the app & I'm also a prime member. It feels like nobody cares at Amazon anymore. I usually ordered products for overnight shipping and could rely on timely delivery by no later than 6am. I have had no fewer than 4 deliveries where shipping info showed out for delivery but suddenly becomes "delivered tomorrow." Customer service chat is one of the worst I've ever encountered. If the agents don't want to answer your questions, they'll ghost you.	Prediction: Negative
# Comment 218: It keeps trying to bill me for prim n i didn't order it	Prediction: Negative
# Comment 219: I have use this in years since I can't reset my password. I use the otp send to my email but it gives me a suspicious activity. I don't work for Amazon so I stop 🛑 right there now I use temu or Alibaba.	Prediction: Negative
# Comment 220: Great app with use friendly interface...	Prediction: Positive
# Comment 221: Keeps getting better and better, and occasional bug. But I submit feedback.	Prediction: Neutral
# Comment 222: Is there any chance of making it possible that when you invite people to see your list that they can remove item and add items to the list and also when invite them they get added to a list that tell you that you have invited them so we see them so we know who is aloud to add or remove items. Thank You.	Prediction: Positive
# Comment 223: RETURN QR CODE IS NOT WORKING ! HECTIC LIFE TOOK ME SEVERAL TIME TO DO THIS PROCESS ABSOLUTELY RIDICULOUS.	Prediction: Negative
# Comment 224: 24h wirh prime they said, they are not able deliver in time anymore and it is not the 1st time. I see no value for being prime client anymore	Prediction: Negative
# Comment 225: I can always find what I want. Fair prices.	Prediction: Positive
# Comment 226: Convenient, Easy, Value shopping. Been here for years will continue..	Prediction: Positive
# Comment 227: Don't expect to get your packages when they say they do. And go ahead and try contacting them You're only going to get automated and never a real person. A new company needs to come out and take over!	Prediction: Negative
# Comment 228: Easy shopping with Amazon, especially if you're disabled and don't drive	Prediction: Positive
# Comment 229: It's been very helpful to get cat food, cat litter, and garbage bags that will actually fit my garbage cans. I also ordered 8 tires for a truck one a month in the past.	Prediction: Positive
# Comment 230: eBay is far better, I pay extra for prime membership for the fast delivery, now I've had to cancel an order because it's already 4 days late, when I contacted them they told me a load of lies and promised it would be delivered yesterday at the latest and then received a message this morning saying it's going to be another 2-3 days!	Prediction: Negative
# Comment 231: When I try to look up my past orders it NEVER loads. I end up having to go to the website to see.	Prediction: Negative
# Comment 232: So much fraud! Knock off products that claim one thing and completely another. This is a nightmare.	Prediction: Negative
# Comment 233: Good app, I keep getting stuff. However, my bank account goes down every time I use this	Prediction: Positive
# Comment 234: I was trying to write a review, but I can't upload pictures.	Prediction: Neutral
# Comment 235: Can't see my orders right now. The windows don't open	Prediction: Negative
# Comment 236: I ordered I package to give to my mom for her birthday and now it's not only almost a week late, I also haven't received any updates on it other than it being delayed in transit.	Prediction: Negative
# Comment 237: Still waiting for a feature to segregate family shopping. Good luck buying suprise gift for the Mrs. Or being recommended diapers after you buy a few kids things.	Prediction: Positive
# Comment 238: It is really laggy and doesn't load properly. It doesn't load when I try to access my Amazon account and cart.	Prediction: Negative
# Comment 239: How there is still no dark mode baffles me. They are missing out on all the night shoppers... Not like it's hurting them financially but still!!! Night mode!!! Sure is a tad janky to navigate as well but. Alright overall..	Prediction: Neutral
# Comment 240: Frustrating.EhatcI don't like is the greedy buyers buying in bulk.Puttingvir on eBay and hiking the price.	Prediction: Negative
# Comment 241: Amazon drivers deliver packages in unsecure locations and bypass one time passwords, I've had so many items left on the sidewalk of my apartment building, including stuff for my wedding. Things go missing, sometimes you don't even get notice of it and then go to check your email and see it was just thrown somewhere. I won't be shopping through them anymore.	Prediction: Negative
# Comment 242: Always closing not able to use it anymore... Please fix the bug	Prediction: Negative
# Comment 243: I give it three because I always have problems with my orders	Prediction: Positive
# Comment 244: Not like it used to be but still a good gem here and there	Prediction: Positive
# Comment 245: Stupid spell check won't let me search what I want to search.	Prediction: Negative
# Comment 246: A fabulous place to go shopping. All your products and convenience thank you amazon	Prediction: Positive
# Comment 247: Do not order from this company in further future because they have stolen good from me which I paid for in full but they have been handing else where to other people and not delivered to my correct address so never trust the amazon company for any further items please go else where to order items because this amazon company doesn't deliver to the correct address given and make out items have been handed to resident when has not been handed to the correct address which haven't received my order	Prediction: Negative
# Comment 248: Good app. Need to add PayPal as an additional payment method turn it'll be 5 stars.	Prediction: Positive
# Comment 249: I would very much like to be able to use the app in English in all countries. My Spanish isn't very good so it's quite difficult to navigate the app in Spanish speaking countries.	Prediction: Positive
# Comment 250: Not sure if it's just me the app crashes and wont let me copy to clipboard, it crashes and gives me an error. It just now started after the update.	Prediction: Negative
# Comment 251: Tha This is for shopping with Amazon. Not food.	Prediction: Positive
# Comment 252: addicted can find good prices on almost everything	Prediction: Positive
# Comment 253: I just love amazon basically find anything so happy days	Prediction: Positive
# Comment 254: No longer opens app when I click on a link from Google or FB. Please fix!	Prediction: Negative
# Comment 255: Crushes my phone battery with barely any usage.	Prediction: Negative
# Comment 256: Good.. Excellent selection of product. Also, available products are listed.	Prediction: Positive
# Comment 257: Has annoying spam notifications enabled by default	Prediction: Negative
# Comment 258: This app sucks aswell as the company itself	Prediction: Negative
# Comment 259: quick and easy to get what I needed thank you	Prediction: Positive
# Comment 260: package not received nothing is being done to rectify this error I've traded with Amazon for a long time this is the worst experience	Prediction: Negative
# Comment 261: Let us use Google Pay or PayPal as a payment option	Prediction: Neutral
# Comment 262: They dont even try to deliver on time	Prediction: Neutral
# Comment 263: The cash grab decision to make a separate fee for ad free will be what drives this into the ground. Rightfully so.	Prediction: Negative
# Comment 264: Has various items galore but some are pricey I findvI have purchased seclveral items and when I wanted to reorder them the prices was more double I found I think its some sort of money making site that prey on people that don't pay attention too closely if you ask me	Prediction: Neutral
# Comment 265: Won't let me load all of my orders when I want to select "not yet dispatched" or the year when I purchased it. It also doesn't show if you purchased the item before when you search for it. Disappointed	Prediction: Negative
# Comment 266: Sluggish, unintuitive navigation. Does the job, though.	Prediction: Neutral
# Comment 267: Love Amazon, great next day delivery on most items.	Prediction: Positive
# Comment 268: They don't have beautiful clothes	Prediction: Positive
# Comment 269: Fantastic partt of liviing sucessfullly...	Prediction: Positive
# Comment 270: Service has gone downhill in the last few years, orders showing up days late, missing items, delivered to the wrong address, or not delivered at all. Customer service sucks.	Prediction: Negative
# Comment 271: I love Amazon it makes shopping so easy to do	Prediction: Positive
# Comment 272: No faults, everything came on time	Prediction: Positive
# Comment 273: I never used but my account credit card no sense for have	Prediction: Neutral
# Comment 274: Always feel safe ordering through this site	Prediction: Positive
# Comment 275: Twice I placed an order for a guaranteed time of delivery and both times they havnt arrived, fix it!	Prediction: Neutral
# Comment 276: Ditching everything Amazon. Half my orders never arrive when they say they will and Prime Video is now charging to upgrade to commercial free. Saw this coming as soon as Freevee was starting to be pushed.	Prediction: Negative
# Comment 277: Made one order, got blacklisted and account closed. You have too much money already, competition is thanking you.	Prediction: Negative
# Comment 278: 3 stars for now because it needs to have a Dark Mode for those of us who's eyes are bothered by the stark white background. Would easily receive 5 Stars if the app was available with Dark Mode.	Prediction: Positive
# ...
# Comment 563: It's alright. I would prefer a more user friendly interface when shopping kind of like the Walmart app. Would be nice if everything was uniform, pretty and easy to understand. I'm currently pregnant and finding my registry took me over 10 minutes. For some reason after clicking a hundred buttons and scrolling through page after page to get to it, it's separated in different categories instead of on one list that everything is on.	Prediction: Positive
# Comment 564: Does most of what you'd expect but not buying Kindle Books. If you want to buy them you need to access Amazon using a browser.	Prediction: Positive
# Comment 565: Not alot of discounts on items. Also the search features doesn't give you the results that you requested it gives you all kinds of items you don't want. It is very frustrating!	Prediction: Negative
# Comment 566: I normally love this app, and since I'm a long-term Prime user I use it fairly often, but lately there have been issues. The current one I'm not happy about it that on the main description of the product it will show one or two day delivery for Prime users, but then when you purchase the item, it changes to 3-5 day delivery. It has happened on three products the last two days. Fix it!!!	Prediction: Neutral
# Comment 567: Scrolling the product and review pages on the Honor Magic 6 Lite is very laggy. Unacceptable as this is a modern phone with a recent processor and 8gb of ram	Prediction: Negative
# Comment 568: Great products at competitive prices, great delivery, returns are straight forward if ever needed	Prediction: Positive
# Comment 569: You have to fix your app, everytime I look at my orders it flashes, its rather annoying to click and wonder what the heck is going on	Prediction: Negative
# Comment 570: Awful customer care experince. The staff was mean, rude and did not help at all.	Prediction: Negative
# Comment 571: The change to the way we see our lists and the steps that we have to go through to get to a specific list are absolutely unnecessary	Prediction: Negative
# Comment 572: New update forces itself into browser text selection menu. Too invasive	Prediction: Negative
# Comment 573: LOVE LOVE LOVE ASSORTMENT OF ITEMS . GREAT PRICING	Prediction: Positive
# Comment 574: The app works well unfortunately on my Android, I can't see my order history past my 10-14 most recent purchases of any given year. I choose the year I want to see in my filters, but after the first few most recently ordered items, in place of the remaining orders, I get row upon row of a search bar saying "Search all orders"? It is very frustrating to have to go to a browser to search and then come back to the app to re-purchase. Could someone please repair this feature.	Prediction: Neutral
# Comment 575: Literally cheating, scamming ignoring, and irresponsible towards customers and customers' money. Please connect me to someone who answers for this. This is literally cheating, scamming and playing with customers mental health. How do you charge for an item that's returned and wait for customer to contact for the refund? What if I'm occupied with something else and doesn't check my transaction trusting Amazon? Are you going to ignore that extra £150 that you charged? You know we all do work hard	Prediction: Negative
# Comment 576: Best app to buy things great prices fast delivery	Prediction: Positive
# Comment 577: I try to let amazon know that I have only received 1 of the items I ordered but the alternative service doesn't ask the appropriate questions	Prediction: Neutral
# Comment 578: Seems to me that when a company drastically increases their fee for membership, there is an expectation of a higher level of service. In my experience, shipping times have gotten worse.... longer than promised. "Free two day shipping with Prime." When was the last time you got something in 2 days? Or " order now and receive by "x". Every time I order something, it's 3 days or more. More often than not, there are delays. Amazon was faster when warehouses were further away.	Prediction: Negative
# Comment 579: I'm very disappointed with Amazon. I bought a Compustar remote for my car from Amazon and after I paid for the installation, I was told that only one of the two remotes are two way and only the one that is one way is working. I reached out to the seller on Amazon and they said I need to get a reference number. And Compustar does not give any services to customers who bought from third party sellers. All my efforts were in vain.	Prediction: Negative
# Comment 580: 1 star bc Amazon don't have Philippines money	Prediction: Negative
# Comment 581: Honestly prime is a hit and miss. If your expecting a package to be delivered the day it shows, don't plan on it.	Prediction: Positive
# Comment 582: I wish they'd optimize it more for samsung. It lags so much on my s23 ultra. Very annoying to use the app.	Prediction: Neutral
# Comment 583: firstly the price increase for prime, then another £3 a month if you don't want ads in your prime videos, and now you often have to pay for next day delivery . All in all Amazon has turned into a disqusting service. That I will never use again after my prime has finished.	Prediction: Negative
# Comment 584: You All at Verizon are sooooo above the rest it's not even a choice which company to go to.. I tell everyone to come to you because you're customer service is GREAT and you're Company is the Best by FAR!!;;; thank you for always being there for me I LOVE you... If I wasn't running late for work I would love to tell you how much that I LOVE your company 😉	Prediction: Positive
# Comment 585: Shop from home, what's not to love?	Prediction: Positive
# Comment 586: Greatly looking forward to the next inevitable class action lawsuit for this company's inability to honor their delivery times. I use it out of necessity, but I tried to go anywhere else for anything, any chance I get. F#&@ Amazon 😑🤬	Prediction: Positive
# Comment 587: Amazon is fine overall, but there's definitely room for improvement. One feature I believe would greatly enhance the user experience is the addition of a "Recommended" page. It would be incredibly helpful to have a dedicated section where the app suggests items similar to those I've viewed or purchased. This would make browsing and discovering new products much more convenient and tailored to my interests.	Prediction: Neutral
# Comment 588: VERY HAPPY CUSTOMERS! My daughters and I order Amazon about 3x a week between all of us. It is so convenient, we ordered all our Christmas, we do all our shopping thru Amazon!!!	Prediction: Positive
# Comment 589: This is good app to look for necessary things definitely recommended	Prediction: Positive
# Comment 590: Keeps your money on lost orders and delets orders our off your order page. These are design features common to the whole platform of Amazon. Expect to chase them around constantly.	Prediction: Negative
# Comment 591: They made it functional and worth using again. The app is back to it's old layout where everything makes sense but the inspire tab is still useless and should have an option to be removed for ease of use and less clutter.	Prediction: Positive
# Comment 592: The packages never arrive when the app says they're going to arrive. At least Walmart and Temu arrive on time. If this continues to happen I will uninstall this app. 🤬🤬	Prediction: Negative
# Comment 593: I love amazon but it didn't let create my account	Prediction: Neutral
# Comment 594: Nice app. Amazon is typical market place. Shop around. This app is annoying so many times I decided to mention it. When reading reviews on pictures, it just gets stuck sometimes and I have to close the review and lose my spot in all my scrolling. Reviews are important. So it's minus 2 stars. Also it lags sometimes.	Prediction: Positive
# Comment 595: Used to love how convenient the app was, but now it spontaneously crashes. Came here to check for an update after several weeks, but nothing new. Disappointed.	Prediction: Negative
# Comment 596: To be honest is better online store them this I'm freaking mad with this store they send you whatever they want and if you try to let a review for that product they cancel the review	Prediction: Negative
# Comment 597: Love Amazon Shopping a lot they have everything you need and it's less cost depending on what you buy. Love Amazon ❤️	Prediction: Positive
# Comment 598: It is a boatware that I cannot uninstall	Prediction: Negative
# Comment 599: Tired seeing pictures of dogs! Keep getting the "something went wrong" messages at random, sometimes after the page has loaded. Annoying AF!	Prediction: Negative
# Comment 600: It was 4 stars but now that they have included ads with prime video... That put a sour taste in my mouth. I was able to get over the shipping delays because they had half way decent movies some of the time. Tubi and freevee have better movies and shows that have ads as well but those streaming platforms are FREE!!!	Prediction: Negative
# Comment 601: Lately I don't even want to use it anymore because it freezes up while searching for items or takes forever to load . I'm considering just deleting it because its just not worth the trouble and is taking too much of my time to find what I want . Most of the time you can find the exact same item on Walmart app without the annoying issues from Amazon app .	Prediction: Negative
# Comment 602: It wasn't let me add anything to cart	Prediction: Negative
# Comment 603: I love shopping on Amazon! I'm able to find what I'm looking for at a reasonable price. The best part about it is that items are delivered to my door.	Prediction: Positive
# Comment 604: Can not pay for items, what is going on lately with this app?	Prediction: Neutral
# Comment 605: They will not let me change my old number to my new smh	Prediction: Negative
# Comment 606: I sometimes have to return items. Sometimes the refunds are very soon after items are returned.	Prediction: Neutral
# Comment 607: The app needs to be optimized, simple actions like browsing and adding things to carts causes it to slow or freeze.	Prediction: Negative
# Comment 608: this is such convenient shopping	Prediction: Positive
# Comment 609: This app has become so sluggish for the past few months. I'm a paying customer, and you'd think because we pay, the developers would do better. Not at all. This app has not been functioning the way it use to.	Prediction: Negative
# Comment 610: I think it's quite silly how,for example in France, English isn't available as a language to use the App.What if i just visited France for a few weeks and i do not understand french and i want to buy something?	Prediction: Neutral
# Comment 611: Always a convenient way to shop.	Prediction: Positive
# Comment 612: stopped crashing which is a major improvement.	Prediction: Negative
# Comment 613: great way to get things quickly	Prediction: Positive
# Comment 614: When did Amazon become Alibaba? The site is full of fake reviews and knockoffs today.	Prediction: Negative
# Comment 615: I yet to use the app I still need to learn about it and how to operate it	Prediction: Neutral
# Comment 616: please make my account private are show what Todo.	Prediction: Neutral
# Comment 617: I love ❤️ shopping with this company. It always has what I need.	Prediction: Positive
# Comment 618: Always there when you need them.	Prediction: Positive
# Comment 619: Want my point back my reward point	Prediction: Positive
# Comment 620: I've been using Amazon 4 a long time, it's Tha Best shopping center u can shop wit online besides Ebay, I believe! I love It!	Prediction: Positive
# Comment 621: Great value top quality items with very fast delivery	Prediction: Positive
# Comment 622: Works fine, after a software updates, not so much. A regular occurrence each time. Just have to wait for bugs to work out. 🙄	Prediction: Neutral
# Comment 623: I'm having some serious issues with this app lately. It's getting stuck loading, it's almost impossible to swipe through pictures, and the share feature only works sometimes. Also can you please put the coupon code section back where it was, it's not easy to find. Which, I guess I get but again already gets a lot of my money lol	Prediction: Neutral
# Comment 624: Love shopping here! They have everything! Prices are awesome too! Reasonable!!!	Prediction: Positive
# Comment 625: I would like to see a feedback button added for general feedback. The new format is good in a lot of ways, but I would like to have the lists go back to where I only have to click once to get to them. Speaking of lists, please allow us to add lightening deals to our lists. We may not be ready to purchase it while it's on sale, but may still want it later.	Prediction: Neutral
# Comment 626: The worst App. If we are talking about delivery..they leave the order outside the door and leave without knocking or calling and I left a note with customer service that let them ring the bell before they run but still they leave the orders and go THE WORST APP EVER أسوأ تطبيق إذا الحديث عن التوصيل حيث يترك الطلب أمام المنزل بدول اتصال او طرق الباب و لقد تركت طلب مع خدمة العملاء بأن يقوم التوصيل بطرق الباب و حتى عدم انتظاري لأفتح و لكن فقط طرق الباب لتنبيهي و مع ذلك لم يتغير شيء أسوأ تطبيق	Prediction: Negative
# Comment 627: The app has been rendered borderline unusable with the latest updates. Constantly jumping around and restarting in the middle of actions. If you try to look at the review overview screen it will just freeze the whole app. Really frustrating. I thought my phone was acting up but now after looking at these app reviews I realize it is not my phone, it is the app itself. Amazon, FIX THIS. It is making me hate shopping with you which i tuought was impossible.	Prediction: Negative
# Comment 628: Search results for hardware is abysmal. I've been searching a lot lately for specialty fasteners and despite selecting "US" (SAE fractions) as a filter, I still get 75%+ of the results in metric sizes. What good is a filter if it's completely ignored?	Prediction: Neutral
# Comment 629: if you can't find what you're looking for on Amazon, you're not trying hard enough	Prediction: Negative
# Comment 630: There is hardly any benefit from using Amazon anymore as Prime benefits diminish while it's prices increase.	Prediction: Neutral
# Comment 631: how many updates this app going to have. I have had 3 in the past week and nothing has changed.	Prediction: Neutral
# Comment 632: Best selling app in Saudi Arabia fast delivery and quality products	Prediction: Positive
# Comment 633: Amazon shopping is a true trusted business with friendly professional people & their strength in customer support is 100% top of the chain. I recommend Amazon Shopping.	Prediction: Positive
# Comment 634: Good app, the only problem that it became a pricey alternative to ali Express.	Prediction: Positive
# Comment 635: I'm officially done using since took my money haven't gave bck my account	Prediction: Negative
# Comment 636: Easy to use and if needed returns are easy to	Prediction: Positive
# Comment 637: Owner vomplete scan first and instsnt analysyd if azaay purpose foe neuro oaycho blastong in mytatuon lasting too hypno..... Mire	Prediction: Negative
# Comment 638: I really like buying on Amazon, every transaction is safe	Prediction: Positive
# Comment 639: Recently after the interface update, it really sucks. I cannot easily find my order and sometimes all my processing order not even show up. Amazon dev. team, before you publish something big change, please kindly gather more user testing before apply.	Prediction: Negative
# Comment 640: Each time I see a recommendation on my notification I click on it hoping it will take me to the app so I can see what the app is recommending but absolutely nothing happens. That's very annoying fix that bug	Prediction: Negative
# Comment 641: Mostly good. Some products are not as good as advertised.	Prediction: Positive
# Comment 642: Don't know what they are doing?!	Prediction: Neutral

# %%
from sklearn.metrics import accuracy_score, balanced_accuracy_score, precision_recall_fscore_support

from sklearn.metrics import accuracy_score, balanced_accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Assuming you have true labels (y_true) and predicted labels (y_pred)
accuracy = accuracy_score(dataset['sentiment'], predictions)
balanced_accuracy = balanced_accuracy_score(dataset['sentiment'], predictions)

# Calculate precision, recall, F1 score, and support for each class
precision, recall, f1, support = precision_recall_fscore_support(dataset['sentiment'], predictions)    

# Create a dictionary to store metrics for each class
class_metrics = {}
for i in range(len(precision)):
    class_metrics[f'class_{i}'] = {
    'precision': precision[i],
    'recall': recall[i],
    'f1': f1[i],
    'support': support[i]
}

print("Accuracy:", accuracy)
print("Balanced Accuracy:", balanced_accuracy)
print("Mean Precision:", np.mean(precision))
print("Mean Recall:", np.mean(recall))
print("Mean F1 Score:", np.mean(f1))

# Print and return the metrics
for class_name, c_metrics in class_metrics.items():
    print(f'{class_name} precision:\t{c_metrics["precision"]}')
    print(f'{class_name} recall:\t{c_metrics["recall"]}')
    print(f'{class_name} f1:\t{c_metrics["f1"]}')
    print(f'{class_name} support:\t{c_metrics["support"]}')

unique_labels = dataset['sentiment'].unique()
conf_matrix = confusion_matrix(dataset['sentiment'], predictions, labels=unique_labels)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 0.7087227414330218
# Balanced Accuracy: 0.7087227414330218
# Mean Precision: 0.704747355889983
# Mean Recall: 0.7087227414330218
# Mean F1 Score: 0.693114713804369
# class_0 precision:	0.6666666666666666
# class_0 recall:	0.8317757009345794
# class_0 f1:	0.7401247401247402
# class_0 support:	214
# class_1 precision:	0.6716417910447762
# class_1 recall:	0.4205607476635514
# class_1 f1:	0.5172413793103449
# class_1 support:	214
# class_2 precision:	0.7759336099585062
# class_2 recall:	0.8738317757009346
# class_2 f1:	0.8219780219780219
# class_2 support:	214
# Confusion Matrix:
# [[187  17  10]
#  [ 45  90  79]
#  [  9  27 178]]

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=unique_labels)

# %%
import matplotlib.pyplot as plt
# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax, cmap=plt.cm.Blues)

# Save the plot as an image file (e.g., PNG)
plt.savefig('confusion_matrix_pT5.png')
plt.savefig('confusion_matrix_pT5.svg')

# Optionally, display the plot
plt.show()

# %%
# Prepare text input
text = "Real good Good deals Get there fast Real quick and good"
encoded_input = tokenizer(text, return_tensors="pt")
encoded_input = {k: v.to(device) for k, v in encoded_input.items()}

# %%
# Perform inference
output = model(**encoded_input)
pred = torch.argmax(output.logits, dim=-1)

# %%
# Decode sentiment
sent = "Negative" if pred.item() == 0 else "Neutral" if pred.item() == 1 else "Positive"

print(f"Text: {text}")
print(f"Sentiment: {sent}")
# Out:
# Text: Real good Good deals Get there fast Real quick and good
# Sentiment: Positive
